# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
df2=pd.read_excel('birth.xlsx')

# %%
df2.shape
# Out:
# (189, 6)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Mom_weight    189 non-null    int64
#  1   Mom_height    189 non-null    int64
#  2   Mom_Age       189 non-null    int64
#  3   Religion      189 non-null    int64
#  4   Gender        189 non-null    int64
#  5   Birth_Weight  189 non-null    float64
# dtypes: float64(1), int64(5)
# memory usage: 9.0 KB

# %%
df2.head()
# Out:
#    Mom_weight  Mom_height  Mom_Age  Religion  Gender  Birth_Weight
# 0          41         152       25         1       1          2.06
# 1          42         157       25         3       1          1.70
# 2          44         153       23         2       1          1.59
# 3          45         177       19         2       1          2.73
# 4          46         160       19         2       1          2.08

# %%
df2.isnull().sum() # Dataset contains no null Values.
# Out:
# Mom_weight      0
# Mom_height      0
# Mom_Age         0
# Religion        0
# Gender          0
# Birth_Weight    0
# dtype: int64

# %%
df2['Gender'].value_counts()
# Out:
# 1    145
# 2     44
# Name: Gender, dtype: int64

# %%
df2['Gender'].replace(2,df2['Gender'].mode()[0],inplace=True)

# %% [markdown]
# ### As we know that birth can be only given by female.so we just replace the other values of Gender coloum with Mode of value of That Column.

# %%
df2['Gender'].value_counts()
# Out:
# 1    189
# Name: Gender, dtype: int64

# %%
df2.describe()
# Out:
#        Mom_weight  Mom_height     Mom_Age    Religion  Gender  Birth_Weight
# count  189.000000  189.000000  189.000000  189.000000   189.0    189.000000
# mean    65.089947  172.026455   23.238095    1.793651     1.0      2.936508
# std      9.966826    8.978363    5.298678    0.808704     0.0      0.645921
# min     41.000000  151.000000   14.000000    1.000000     1.0      1.500000
# 25%     59.000000  166.000000   19.000000    1.000000     1.0      2.440000
# 50%     69.000000  174.000000   23.000000    2.000000     1.0      2.980000
# 75%     73.000000  178.000000   26.000000    2.000000     1.0      3.440000
# max     79.000000  189.000000   45.000000    3.000000     1.0      4.150000

# %%
plt.figure(figsize=(11,7))
sns.boxplot(df2);

# %% [markdown]
# ### From above Figure we can clearly see some Outliers.

# %% [markdown]
# ### Now,we are going to remove all Outliers.

# %%
min_thresold, max_thresold = df2.Birth_Weight.quantile([0.001,0.999])
min_thresold, max_thresold
# Out:
# (1.51692, 4.142480000000001)

# %%
df2_birth_weight = df2[(df2.Birth_Weight<max_thresold) & (df2.Birth_Weight>min_thresold)]
df2_birth_weight.shape
# Out:
# (187, 6)

# %%
min_thresold, max_thresold = df2.Mom_Age.quantile([0.001,0.999])
min_thresold, max_thresold
# Out:
# (14.0, 43.308000000000106)

# %%
df2_Age = df2[(df2.Mom_Age<max_thresold) & (df2.Mom_Age>min_thresold)]
df2_Age.shape
# Out:
# (185, 6)

# %%
min_thresold, max_thresold = df2.Mom_weight.quantile([0.001,0.999])
min_thresold, max_thresold
# Out:
# (41.0, 79.0)

# %%
df2_final = df2[(df2.Mom_weight<max_thresold) & (df2.Mom_weight>min_thresold)]
df2_final.shape
# Out:
# (183, 6)

# %%
x = df2_final.describe()
print(x)
# Out:
#        Mom_weight  Mom_height     Mom_Age    Religion  Gender  Birth_Weight
# count  183.000000  183.000000  183.000000  183.000000   183.0    183.000000
# mean    65.464481  172.218579   23.349727    1.781421     1.0      2.947978
# std      9.358994    8.764080    5.298568    0.802663     0.0      0.635389
# min     42.000000  151.000000   14.000000    1.000000     1.0      1.500000
# 25%     59.500000  167.000000   19.000000    1.000000     1.0      2.460000
# 50%     69.000000  174.000000   23.000000    2.000000     1.0      2.980000
# 75%     73.000000  178.000000   26.500000    2.000000     1.0      3.430000
# max     78.000000  189.000000   45.000000    3.000000     1.0      4.150000

# %%
x = df2_final.corr()
print(x)
# Out:
#               Mom_weight  Mom_height   Mom_Age  Religion  Gender  Birth_Weight
# Mom_weight      1.000000    0.492319  0.109279  0.081611     NaN      0.789842
# Mom_height      0.492319    1.000000  0.064132 -0.043159     NaN      0.623325
# Mom_Age         0.109279    0.064132  1.000000 -0.000014     NaN      0.074469
# Religion        0.081611   -0.043159 -0.000014  1.000000     NaN      0.144140
# Gender               NaN         NaN       NaN       NaN     NaN           NaN
# Birth_Weight    0.789842    0.623325  0.074469  0.144140     NaN      1.000000

# %%
plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.heatmap(df2_final.corr(),
            cmap = 'Blues',
            annot = True)
plt.title('The correlation Map for the Data', fontsize = 20)
plt.show()

# %% [markdown]
# ### Insight:- In upper heatmap, we clearly see a strong positive corelation b/w Mom_weight & Birth_weight.which means if the Mom weight increases then birth_weight will also increases

# %%
x = df2_final.cov()
x.style.bar(color = 'gold', align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.4%, gold 0.4%, gold 52.8%, transparent 52.8%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 19.3%, transparent 19.3%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.0%, gold 32.0%, gold 96.7%, transparent 96.7%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 46.1%, transparent 46.1%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.4%, gold 0.4%, gold 100.0%, transparent 100.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 10.6%, transparent 10.6%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 32.0%, transparent 32.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row1_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 73.9%, transparent 73.9%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 6.2%, transparent 6.2%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.4%, gold 0.4%, gold 4.3%, transparent 4.3%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 100.0%, transparent 100.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.0%, gold 32.0%, gold 32.0%, transparent 32.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row2_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 5.3%, transparent 5.3%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.7%, transparent 0.7%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.4%, transparent 0.4%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.0%, gold 32.0%, gold 100.0%, transparent 100.0%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row3_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.6%, transparent 1.6%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row4_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row4_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row4_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row4_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row4_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row4_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 5.4%, transparent 5.4%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.4%, gold 0.4%, gold 4.9%, transparent 4.9%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 0.9%, transparent 0.9%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.0%, gold 32.0%, gold 39.8%, transparent 39.8%);
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row5_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_ede86d4c_5345_11eb_96d9_80a5893ab660row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 8.6%, transparent 8.6%);
#         }</style><table id="T_ede86d4c_5345_11eb_96d9_80a5893ab660" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mom_weight</th>        <th class="col_heading level0 col1" >Mom_height</th>        <th class="col_heading level0 col2" >Mom_Age</th>        <th class="col_heading level0 col3" >Religion</th>        <th class="col_heading level0 col4" >Gender</th>        <th class="col_heading level0 col5" >Birth_Weight</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ede86d4c_5345_11eb_96d9_80a5893ab660level0_row0" class="row_heading level0 row0" >Mom_weight</th>
#                         <td id="T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col0" class="data row0 col0" >87.590764</td>
#                         <td id="T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col1" class="data row0 col1" >40.381433</td>
#                         <td id="T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col2" class="data row0 col2" >5.419084</td>
#                         <td id="T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col3" class="data row0 col3" >0.613073</td>
#                         <td id="T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_ede86d4c_5345_11eb_96d9_80a5893ab660row0_col5" class="data row0 col5" >4.696878</td>
#             </tr>
#             <tr>
#                         <th id="T_e

# %%
plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

sns.heatmap(df2_final.cov(),
            cmap = 'Greens',
            annot = True)
plt.title('The covariance for the Data', fontsize = 20)
plt.show()

# %% [markdown]
# ### insight:- from this heat map we can analyed the data and make a decision that the covariance between Mom Weight and Birth_weight is vary high and Somehow Covariance of Mom Height is Also Good with Birth_weight. so that we can say that all three Columns data move together in the dataset.

# %%
plt.figure(figsize=(16,7))
sns.pairplot(df2_final)
plt.show()

# %% [markdown]
# ### Insight:- In above Pairplot we can clearly see the positive Linear relationship b/w Mom_weight & Mom_height with  Birth_weight. which means If Mom_weight and Mom_height increase Than Birth_weight will also Increase.

# %% [markdown]
# ## Seprating the independent and dependent Variables from Dataset

# %%
x = df2_final.drop(columns=['Birth_Weight'])

# %%
y = df2_final['Birth_Weight']

# %%
x.head()
# Out:
#    Mom_weight  Mom_height  Mom_Age  Religion  Gender
# 1          42         157       25         3       1
# 2          44         153       23         2       1
# 3          45         177       19         2       1
# 4          46         160       19         2       1
# 5          46         167       24         1       1

# %%
y.head()
# Out:
# 1    1.70
# 2    1.59
# 3    2.73
# 4    2.08
# 5    2.10
# Name: Birth_Weight, dtype: float64

# %% [markdown]
# ## Training and Testing of a Dataset

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1,random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
Accuracy_score = r2_score(y_pred,y_test)

# %%
Accuracy_score
# Out:
# 0.6877741270156041

# %% [markdown]
# ### Insight:-Here, we can see that the Accuracy Score is not so good,it is beacuse we have a less no. of data in a dataset to train and test.But We will Try Another Algorithm like Random Forest Regressor.

# %% [markdown]
# ### Testing the Model

# %%
baby_weight = [[41,147,24,2,1]]
print(regressor.predict(baby_weight))
# Out:
# [1.35831998]

# %% [markdown]
# ### From the above evaluation of Linear Regression Model we can see by giving input values.The baby_weight is 1.35kg.

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RFreg = RandomForestRegressor(n_estimators=10,random_state=0)

# %% [markdown]
# ## Training & Testing The Dataset

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.32,random_state=0)

# %%
RFreg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_predict = RFreg.predict(x_test)

# %%
Accuracy_rand_reg = r2_score(y_test,y_predict)

# %%
Accuracy_rand_reg
# Out:
# 0.8078925714177918

# %% [markdown]
# ## Here,we can see that we are getting much good Accuracy by using Random Forest Regressor as Compare to  Linear Regression.

# %%
baby_weight_new = [[41,147,24,2,1]]
print(RFreg.predict(baby_weight_new))
# Out:
# [1.634]

# %% [markdown]
# ## From the above evaluation of Random Forest Regressor we can see by giving input values.The baby_weight_new is 1.63kg.
